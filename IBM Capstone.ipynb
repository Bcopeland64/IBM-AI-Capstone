# %% [markdown]
# <a href="http://cocl.us/pytorch_link_top">
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0110EN/notebook_images%20/Pytochtop.png" width="750" alt="IBM Product " />
# </a>

# %% [markdown]
# <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0110EN/notebook_images%20/cc-logo-square.png" width="200" alt="cognitiveclass.ai logo" />

# %% [markdown]
# <h1><h1>Pre-trained-Models with PyTorch </h1>

# %% [markdown]
# In this lab, you will use pre-trained models to classify between the negative and positive samples; you will be provided with the dataset object. The particular pre-trained model will be resnet18; you will have three questions:
# <ul>
# <li>change the output layer</li>
# <li> train the model</li>
# <li>  identify  several  misclassified samples</li>
#  </ul>
# You will take several screenshots of your work and share your notebook.

# %% [markdown]
# <h2>Table of Contents</h2>

# %% [markdown]
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#
#
# <ul>
#     <li><a href="#download_data"> Download Data</a></li>
#     <li><a href="#auxiliary"> Imports and Auxiliary Functions </a></li>
#     <li><a href="#data_class"> Dataset Class</a></li>
#     <li><a href="#Question_1">Question 1</a></li>
#     <li><a href="#Question_2">Question 2</a></li>
#     <li><a href="#Question_3">Question 3</a></li>
# </ul>
# <p>Estimated Time Needed: <strong>120 min</strong></p>
#  </div>
# <hr>

# %% [markdown]
# <h2 id="download_data">Download Data</h2>

# %% [markdown]
# Download the dataset and unzip the files in your data directory, unlike the other labs, all the data will be deleted after you close  the lab, this may take some time:

# %%
# !wget https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0321EN/data/images/Positive_tensors.zip
# Out:
# --2020-05-21 22:14:06--  https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0321EN/data/images/Positive_tensors.zip
# Resolving s3-api.us-geo.objectstorage.softlayer.net (s3-api.us-geo.objectstorage.softlayer.net)... 67.228.254.196
# Connecting to s3-api.us-geo.objectstorage.softlayer.net (s3-api.us-geo.objectstorage.softlayer.net)|67.228.254.196|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2598656062 (2.4G) [application/zip]
# Saving to: ‘Positive_tensors.zip’
#
# 100%[====================================>] 2,598,656,062 34.3MB/s   in 70s
#
# 2020-05-21 22:15:17 (35.5 MB/s) - ‘Positive_tensors.zip’ saved [2598656062/2598656062]

# %%
# !unzip -q Positive_tensors.zip

# %%
! wget https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0321EN/data/images/Negative_tensors.zip
# !unzip -q Negative_tensors.zip
# Out:
# --2020-05-21 22:18:04--  https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0321EN/data/images/Negative_tensors.zip
# Resolving s3-api.us-geo.objectstorage.softlayer.net (s3-api.us-geo.objectstorage.softlayer.net)... 67.228.254.196
# Connecting to s3-api.us-geo.objectstorage.softlayer.net (s3-api.us-geo.objectstorage.softlayer.net)|67.228.254.196|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2111408108 (2.0G) [application/zip]
# Saving to: ‘Negative_tensors.zip’
#
# 100%[====================================>] 2,111,408,108 33.6MB/s   in 59s
#
# 2020-05-21 22:19:04 (34.2 MB/s) - ‘Negative_tensors.zip’ saved [2111408108/2111408108]

# %% [markdown]
# We will install torchvision:

# %%
# !pip install torchvision
# Out:
# Collecting torchvision
#   Downloading https://files.pythonhosted.org/packages/61/51/aa2770a70f612ce9a2fc7da3a1a93f9ecf8746788256fed6b691f9b31ca9/torchvision-0.6.0-cp36-cp36m-manylinux1_x86_64.whl (6.6MB)
#      |████████████████████████████████| 6.6MB 4.2MB/s eta 0:00:01
# Collecting torch==1.5.0 (from torchvision)
#   Downloading https://files.pythonhosted.org/packages/13/70/54e9fb010fe1547bc4774716f11ececb81ae5b306c05f090f4461ee13205/torch-1.5.0-cp36-cp36m-manylinux1_x86_64.whl (752.0MB)
#      |████████████████████████████████| 752.0MB 22kB/s s eta 0:00:01                        | 94.2MB 35.0MB/s eta 0:00:19                    | 118.9MB 37.3MB/s eta 0:00:17
# Requirement already satisfied: numpy in /opt/conda/envs/Python36/lib/python3.6/site-packages (from torchvision) (1.15.4)
# Requirement already satisfied: pillow>=4.1.1 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from torchvision) (5.4.1)
# Requirement already satisfied: future in /opt/conda/envs/Python36/lib/python3.6/site-packages (from torch==1.5.0->torchvision) (0.17.1)
# Installing collected packages: torch, torchvision
# Successfully installed torch-1.5.0 torchvision-0.6.0

# %% [markdown]
# <h2 id="auxiliary">Imports and Auxiliary Functions</h2>

# %% [markdown]
# The following are the libraries we are going to use for this lab. The <code>torch.manual_seed()</code> is for forcing the random function to give the same number every time we try to recompile it.

# %%
# These are the libraries will be used for this lab.
import torchvision.models as models
from PIL import Image
import pandas
from torchvision import transforms
import torch.nn as nn
import time
import torch 
import matplotlib.pylab as plt
import numpy as np
from torch.utils.data import Dataset, DataLoader
import h5py
import os
import glob
torch.manual_seed(0)

# %%
from matplotlib.pyplot import imshow
import matplotlib.pylab as plt
from PIL import Image
import pandas as pd
import os

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# <h2 id="data_class">Dataset Class</h2>

# %% [markdown]
#  This dataset class is essentially the same dataset you build in the previous section, but to speed things up, we are going to use tensors instead of jpeg images. Therefor for each iteration, you will skip the reshape step, conversion step to tensors and normalization step.

# %%
# Create your own dataset object

class Dataset(Dataset):

    # Constructor
    def __init__(self,transform=None,train=True):
        directory="/home/dsxuser/work"
        positive="Positive_tensors"
        negative='Negative_tensors'

        positive_file_path=os.path.join(directory,positive)
        negative_file_path=os.path.join(directory,negative)
        positive_files=[os.path.join(positive_file_path,file) for file in os.listdir(positive_file_path) if file.endswith(".pt")]
        negative_files=[os.path.join(negative_file_path,file) for file in os.listdir(negative_file_path) if file.endswith(".pt")]
        number_of_samples=len(positive_files)+len(negative_files)
        self.all_files=[None]*number_of_samples
        self.all_files[::2]=positive_files
        self.all_files[1::2]=negative_files 
        # The transform is goint to be used on image
        self.transform = transform
        #torch.LongTensor
        self.Y=torch.zeros([number_of_samples]).type(torch.LongTensor)
        self.Y[::2]=1
        self.Y[1::2]=0
        
        if train:
            self.all_files=self.all_files[0:30000]
            self.Y=self.Y[0:30000]
            self.len=len(self.all_files)
        else:
            self.all_files=self.all_files[30000:]
            self.Y=self.Y[30000:]
            self.len=len(self.all_files)     
       
    # Get the length
    def __len__(self):
        return self.len
    
    # Getter
    def __getitem__(self, idx):
               
        image=torch.load(self.all_files[idx])
        y=self.Y[idx]
                  
        # If there is any transform method, apply it onto the image
        if self.transform:
            image = self.transform(image)

        return image, y
    
print("done")
# Out:
# done

# %%
def get_default_device():
 
  if torch.cuda.is_available():  
    print("Using GPU")
    return torch.device("cuda")  

  print("Using CPU")
  return torch.device("cpu")
# end def

use_cuda = True  # Use GPU
device = torch.device("cpu")
if use_cuda:
  device = get_default_device()
# Out:
# Using CPU

# %% [markdown]
# We create two dataset objects, one for the training data and one for the validation data.

# %%
train_dataset = Dataset(train=True)
validation_dataset = Dataset(train=False)
print("done")
# Out:
# done

# %% [markdown]
# <h2 id="Question_1">Question 1</h2>

# %% [markdown]
# <b>Prepare a pre-trained resnet18 model :</b>

# %% [markdown]
# <b>Step 1</b>: Load the pre-trained model <code>resnet18</code> Set the parameter <code>pretrained</code> to true:

# %%
# Step 1: Load the pre-trained model resnet18

import torchvision.models as models

model = models.resnet18(pretrained=True)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-5c106cde.pth" to /home/dsxuser/.cache/torch/checkpoints/resnet18-5c106cde.pth
# HBox(children=(IntProgress(value=0, max=46827520), HTML(value='')))

# %% [markdown]
# <b>Step 2</b>: Set the attribute <code>requires_grad</code> to <code>False</code>. As a result, the parameters will not be affected by training.

# %%
# Step 2: Set the parameter cannot be trained for the pre-trained model


for param in model.parameters():
    param.requires_grad = False

# %% [markdown]
# <code>resnet18</code> is used to classify 1000 different objects; as a result, the last layer has 1000 outputs.  The 512 inputs come from the fact that the previously hidden layer has 512 outputs.

# %% [markdown]
# <b>Step 3</b>: Replace the output layer <code>model.fc</code> of the neural network with a <code>nn.Linear</code> object, to classify 2 different classes. For the parameters <code>in_features </code> remember the last hidden layer has 512 neurons.

# %%
d_hidden = 512
d_out = 2

model.fc = nn.Linear(d_hidden, d_out)

# %% [markdown]
# Print out the model in order to show whether you get the correct answer.<br> <b>(Your peer reviewer is going to mark based on what you print here.)</b>

# %%
print(model)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=2, bias=True)
# )

# %% [markdown]
# <h2 id="Question_2">Question 2: Train the Model</h2>

# %% [markdown]
# In this question you will train your, model:

# %% [markdown]
# <b>Step 1</b>: Create a cross entropy criterion function

# %%
# Step 1: Create the loss function

criterion = nn.CrossEntropyLoss()

# %% [markdown]
# <b>Step 2</b>: Create a training loader and validation loader object, the batch size should have 100 samples each.

# %%
batch_size = 100
train_loader = torch.utils.data.DataLoader(dataset=train_dataset, batch_size=batch_size)
validation_loader = torch.utils.data.DataLoader(dataset=validation_dataset, batch_size=batch_size)

# %% [markdown]
# <b>Step 3</b>: Use the following optimizer to minimize the loss

# %%
optimizer = torch.optim.Adam([parameters  for parameters in model.parameters() if parameters.requires_grad],lr=0.001)

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# **Complete the following code to calculate  the accuracy on the validation data for one epoch; this should take about 45 minutes. Make sure you calculate the accuracy on the validation data.**

# %%
n_epochs = 1
loss_list = []
accuracy_list = []
accuracy = 0
correct = 0
N_test = len(validation_dataset)
N_train = len(train_dataset)
start_time = time.time()
#n_epochs

print("Number of items in training set : ", N_train)
print("Number of items in testing set : ", N_test)

running_loss = 0
start_time = time.time()
for epoch in range(n_epochs):
    for i, (x, y) in enumerate(train_loader):        
        print('-' * 30)
        print('Iteration (train phase) {}/{}'.format(i+1, int(N_train/batch_size)))
        i_start_time = time.time()
        
        x = x.to(device)
        y = y.to(device)
            
        # set model to train 
        model.train() 
        
        # clear gradient 
        optimizer.zero_grad()
     
        # make a prediction 
        z = model(x)
   
        # calculate loss 
        loss = criterion(z, y) 
        # loss.requires_grad = True
    
        # calculate gradients of parameters 
        loss.backward()
        
        # update parameters 
        optimizer.step()
        
        loss_list.append(loss.data)
        print("Finished in {} (s)".format(time.time()-i_start_time))
    
        
    correct=0
    for i, (x_test, y_test) in enumerate(validation_loader):
        print('-' * 30)
        print('Iteration (validation phase) {}/{}'.format(i+1, int(N_test/batch_size)))
        i_start_time = time.time()
        
        x_test = x_test.to(device)
        y_test = y_test.to(device)
        
        # set model to eval 
        model.eval()
       
        # make a prediction 
        z = model(x_test)
        
        # find max 
        _, yhat = torch.max(z.data, 1)
       
       
        #Calculate misclassified  samples in mini-batch 
        #hint +=(yhat==y_test).sum().item()
        correct += (yhat==y_test).sum().item()  
        
        print("Finished in {} (s)".format(time.time()-i_start_time))
   
    
    accuracy=correct/N_test
    print("Epoch %d - accuracy: %.3f" % (epoch+1, accuracy))
    
    accuracy_list.append(accuracy)
    print("-" * 72)
    
    # Save model
    model_file_path = model_path + "resnet18_trained_model_epoch_{}.pth".format(epoch+1)
    torch.save(model.state_dict(), model_file_path)
    
    # Duration for epoch
    print("Finished epoch {} in {} (s).".format(epoch+1, time.time()-start_time))
# Out:
# Number of items in training set :  30000
# Number of items in testing set :  10000
# ------------------------------
# Iteration (train phase) 1/300
# Finished in 6.276322603225708 (s)
# ------------------------------
# Iteration (train phase) 2/300
# Finished in 6.074628829956055 (s)
# ------------------------------
# Iteration (train phase) 3/300
# Finished in 6.113900661468506 (s)
# ------------------------------
# Iteration (train phase) 4/300
# Finished in 6.0670788288116455 (s)
# ------------------------------
# Iteration (train phase) 5/300
# Finished in 6.114424228668213 (s)
# ------------------------------
# Iteration (train phase) 6/300
# Finished in 6.095987558364868 (s)
# ------------------------------
# Iteration (train phase) 7/300
# Finished in 6.074311971664429 (s)
# ------------------------------
# Iteration (train phase) 8/300
# Finished in 6.079434394836426 (s)
# ------------------------------
# Iteration (train phase) 9/300
# Finished in 6.079158067703247 (s)
# ------------------------------
# Iteration (train phase) 10/300
# Finished in 6.129587411880493 (s)
# ------------------------------
# Iteration (train phase) 11/300
# Finished in 6.144038200378418 (s)
# ------------------------------
# Iteration (train phase) 12/300
# Finished in 6.063895225524902 (s)
# ------------------------------
# Iteration (train phase) 13/300
# Finished in 6.100220203399658 (s)
# ------------------------------
# Iteration (train phase) 14/300
# Finished in 6.077096223831177 (s)
# ------------------------------
# Iteration (train phase) 15/300
# Finished in 6.124520540237427 (s)
# ------------------------------
# Iteration (train phase) 16/300
# Finished in 6.119341135025024 (s)
# ------------------------------
# Iteration (train phase) 17/300
# Finished in 6.123265027999878 (s)
# ------------------------------
# Iteration (train phase) 18/300
# Finished in 6.044785499572754 (s)
# ------------------------------
# Iteration (train phase) 19/300
# Finished in 6.04012131690979 (s)
# ------------------------------
# Iteration (train phase) 20/300
# Finished in 6.044605016708374 (s)
# ------------------------------
# Iteration (train phase) 21/300
# Finished in 6.099541187286377 (s)
# ------------------------------
# Iteration (train phase) 22/300
# Finished in 5.956665992736816 (s)
# ------------------------------
# Iteration (train phase) 23/300
# Finished in 6.040668725967407 (s)
# ------------------------------
# Iteration (train phase) 24/300
# Finished in 6.053307294845581 (s)
# ------------------------------
# Iteration (train phase) 25/300
# Finished in 6.055195331573486 (s)
# ------------------------------
# Iteration (train phase) 26/300
# Finished in 6.09560751914978 (s)
# ------------------------------
# Iteration (train phase) 27/300
# Finished in 6.10851526260376 (s)
# ------------------------------
# Iteration (train phase) 28/300
# Finished in 6.100888967514038 (s)
# ------------------------------
# Iteration (train phase) 29/300
# Finished in 6.091985464096069 (s)
# ------------------------------
# Iteration (train phase) 30/300
# Finished in 6.130957365036011 (s)
# ------------------------------
# Iteration (train phase) 31/300
# Finished in 6.1065521240234375 (s)
# ------------------------------
# Iteration (train phase) 32/300
# Finished in 6.058971166610718 (s)
# ------------------------------
# Iteration (train phase) 33/300
# Finished in 6.117684364318848 (s)
# ------------------------------
# Iteration (train phase) 34/300
# Finished in 6.114185333251953 (s)
# ------------------------------
# Iteration (train phase) 35/300
# Finished in 6.1659095287323 (s)
# ------------------------------
# Iteration (train phase) 36/300
# Finished in 6.103536605834961 (s)
# ------------------------------
# Iteration (train phase) 37/300
# Finished in 6.097703695297241 (s)
# ------------------------------
# Iteration (train phase) 38/300
# Finished in 6.098074197769165 (s)
# ------------------------------
# Iteration (train phase) 39/300
# Finished in 6.100449800491333 (s)
# ------------------------------
# Iteration (train phase) 40/300
# Finished in 6.0331032276153564 (s)
# ------------------------------
# Iteration (train phase) 41/300
# Finished in 6.115402936935425 (s)
# ------------------------------
# Iteration (train phase) 42/300
# Finished in 6.13966703414917 (s)
# ------------------------------
# Iteration (train phase) 43/300
# Finished in 6.140198230743408 (s)
# ------------------------------
# Iteration (train phase) 44/300
# Finished in 6.029263973236084 (s)
# ------------------------------
# Iteration (train phase) 45/300
# Finished in 6.147385358810425 (s)
# ------------------------------
# Iteration (train phase) 46/300
# Finished in 6.2237303256988525 (s)
# ------------------------------
# Iteration (train phase) 47/300
# Finished in 6.150975942611694 (s)
# ------------------------------
# Iteration (train phase) 48/300
# Finished in 6.155184984207153 (s)
# ------------------------------
# Iteration (train phase) 49/300
# Finished in 6.165896892547607 (s)
# ------------------------------
# Iteration (train phase) 50/300
# Finished in 6.0956902503967285 (s)
# ------------------------------
# Iteration (train phase) 51/300
# Finished in 6.056989669799805 (s)
# ------------------------------
# Iteration (train phase) 52/300
# Finished in 6.134805202484131 (s)
# ------------------------------
# Iteration (train phase) 53/300
# Finished in 6.186780214309692 (s)
# ------------------------------
# Iteration (train phase) 54/300
# Finished in 6.3309409618377686 (s)
# ------------------------------
# Iteration (train phase) 55/300
# Finished in 6.277807712554932 (s)
# ------------------------------
# Iteration (train phase) 56/300
# Finished in 6.096362113952637 (s)
# ------------------------------
# Iteration (train phase) 57/300
# Finished in 6.191852807998657 (s)
# ------------------------------
# Iteration (train phase) 58/300
# Finished in 6.0910704135894775 (s)
# ------------------------------
# Iteration (train phase) 59/300
# Finished in 6.134239196777344 (s)
# ------------------------------
# Iteration (train phase) 60/300
# Finished in 6.2338433265686035 (s)
# ------------------------------
# Iteration (train phase) 61/300
# Finished in 6.114071846008301 (s)
# ------------------------------
# Iteration (train phase) 62/300
# Finished in 6.1035871505737305 (s)
# ------------------------------
# Iteration (train phase) 63/300
# Finished in 6.214176893234253 (s)
# ------------------------------
# Iteration (train phase) 64/300
# Finished in 6.1550493240356445 (s)
# ------------------------------
# Iteration (train phase) 65/300
# Finished in 6.0608673095703125 (s)
# ------------------------------
# Iteration (train phase) 66/300
# Finished in 6.129334926605225 (s)
# ------------------------------
# Iteration (train phase) 67/300
# Finished in 6.135173320770264 (s)
# ------------------------------
# Iteration (train phase) 68/300
# Finished in 6.169447660446167 (s)
# ------------------------------
# Iteration (train phase) 69/300
# Finished in 6.128029823303223 (s)
# ------------------------------
# Iteration (train phase) 70/300
# Finished in 6.244664192199707 (s)
# ------------------------------
# Iteration (train phase) 71/300
# Finished in 6.162557601928711 (s)
# ------------------------------
# Iteration (train phase) 72/300
# Finished in 6.040634632110596 (s)
# ------------------------------
# Iteration (train phase) 73/300
# Finished in 6.188928842544556 (s)
# ------------------------------
# Iteration (train phase) 74/300
# Finished in 6.1027748584747314 (s)
# ------------------------------
# Iteration (train phase) 75/300
# Finished in 6.283381462097168 (s)
# ------------------------------
# Iteration (train phase) 76/300
# Finished in 6.131592035293579 (s)
# ------------------------------
# Iteration (train phase) 77/300
# Finished in 6.116204261779785 (s)
# ------------------------------
# Iteration (train phase) 78/300
# Finished in 6.1643476486206055 (s)
# ------------------------------
# Iteration (train phase) 79/300
# Finished in 6.113050699234009 (s)
# ------------------------------
# Iteration (train phase) 80/300
# Finished in 6.1949782371521 (s)
# ------------------------------
# Iteration (train phase) 81/300
# Finished in 6.089910507202148 (s)
# ------------------------------
# Iteration (train phase) 82/300
# Finished in 6.134577989578247 (s)
# ------------------------------
# Iteration (train phase) 83/300
# Finished in 6.0775251388549805 (s)
# ------------------------------
# Iteration (train phase) 84/300
# Finished in 6.184058666229248 (s)
# ------------------------------
# Iteration (train phase) 85/300
# Finished in 6.1990790367126465 (s)
# ------------------------------
# Iteration (train phase) 86/300
# Finished in 6.138848543167114 (s)
# ------------------------------
# Iteration (train phase) 87/300
# Finished in 6.12882399559021 (s)
# ------------------------------
# Iteration (train phase) 88/300
# Finished in 6.091527700424194 (s)
# ------------------------------
# Iteration (train phase) 89/300
# Finished in 6.170183420181274 (s)
# ------------------------------
# Iteration (train phase) 90/300
# Finished in 6.021716833114624 (s)
# ------------------------------
# Iteration (train phase) 91/300
# Finished in 6.091613531112671 (s)
# ------------------------------
# Iteration (train phase) 92/300
# Finished in 6.021199464797974 (s)
# ------------------------------
# Iteration (train phase) 93/300
# Finished in 6.082027912139893 (s)
# ------------------------------
# Iteration (train phase) 94/300
# Finished in 6.130000829696655 (s)
# ------------------------------
# Iteration (train phase) 95/300
# Finished in 6.158413648605347 (s)
# ------------------------------
# Iteration (train phase) 96/300
# Finished in 6.1147239208221436 (s)
# ------------------------------
# Iteration (train phase) 97/300
# Finished in 6.159931182861328 (s)
# ------------------------------
# Iteration (train phase) 98/300
# Finished in 6.174468994140625 (s)
# ------------------------------
# Iteration (train phase) 99/300
# Finished in 6.146776437759399 (s)
# ------------------------------
# Iteration (train phase) 100/300
# Finished in 6.19379448890686 (s)
# ------------------------------
# Iteration (train phase) 101/300
# Finished in 6.062302589416504 (s)
# ------------------------------
# Iteration (train phase) 102/300
# Finished in 6.081019401550293 (s)
# ------------------------------
# Iteration (train phase) 103/300
# Finished in 6.057878255844116 (s)
# ------------------------------
# Iteration (train phase) 104/300
# Finished in 6.096967935562134 (s)
# ------------------------------
# Iteration (train phase) 105/300
# Finished in 6.239339351654053 (s)
# ------------------------------
# Iteration (train phase) 106/300
# Finished in 6.17309045791626 (s)
# ------------------------------
# Iteration (train phase) 107/300
# Finished in 6.109686613082886 (s)
# ------------------------------
# Iteration (train phase) 108/300
# Finished in 6.19896674156189 (s)
# ------------------------------
# Iteration (train phase) 109/300
# Finished in 6.073576927185059 (s)
# ------------------------------
# Iteration (train phase) 110/300
# Finished in 6.123280763626099 (s)
# ------------------------------
# Iteration (train phase) 111/300
# Finished in 6.236367702484131 (s)
# ------------------------------
# Iteration (train phase) 112/300
# Finished in 6.324629545211792 (s)
# ------------------------------
# Iteration (train phase) 113/300
# Finished in 6.1141111850738525 (s)
# ------------------------------
# Iteration (train phase) 114/300
# Finished in 6.127887964248657 (s)
# ------------------------------
# Iteration (train phase) 115/300
# Finished in 6.09943699836731 (s)
# ------------------------------
# Iteration (train phase) 116/300
# Finished in 6.0842366218566895 (s)
# ------------------------------
# Iteration (train phase) 117/300
# Finished in 6.082481861114502 (s)
# ------------------------------
# Iteration (train phase) 118/300
# Finished in 6.154124021530151 (s)
# ------------------------------
# Iteration (train phase) 119/300
# Finished in 6.093434810638428 (s)
# ------------------------------
# Iteration (train phase) 120/300
# Finished in 6.166278123855591 (s)
# ------------------------------
# Iteration (train phase) 121/300
# Finished in 6.075110912322998 (s)
# ------------------------------
# Iteration (train phase) 122/300
# Finished in 6.097627639770508 (s)
# ------------------------------
# Iteration (train phase) 123/300
# Finished in 6.189326524734497 (s)
# ------------------------------
# Iteration (train phase) 124/300
# Finished in 6.064187526702881 (s)
# ------------------------------
# Iteration (train phase) 125/300
# Finished in 6.072277069091797 (s)
# ------------------------------
# Iteration (train phase) 126/300
# Finished in 6.131466388702393 (s)
# ------------------------------
# Iteration (train phase) 127/300
# Finished in 6.23434591293335 (s)
# ------------------------------
# Iteration (train phase) 128/300
# Finished in 6.139670133590698 (s)
# ------------------------------
# Iteration (train phase) 129/300
# Finished in 6.06783652305603 (s)
# ------------------------------
# Iteration (train phase) 130/300
# Finished in 6.183260917663574 (s)
# ------------------------------
# Iteration (train phase) 131/300
# Finished in 6.152636289596558 (s)
# ------------------------------
# Iteration (train phase) 132/300
# Finished in 6.256388187408447 (s)
# ------------------------------
# Iteration (train phase) 133/300
# Finished in 6.152457237243652 (s)
# ------------------------------
# Iteration (train phase) 134/300
# Finished in 6.249933242797852 (s)
# ------------------------------
# Iteration (train phase) 135/300
# Finished in 6.2072412967681885 (s)
# ------------------------------
# Iteration (train phase) 136/300
# Finished in 6.124792575836182 (s)
# ------------------------------
# Iteration (train phase) 137/300
# Finished in 6.207240104675293 (s)
# ------------------------------
# Iteration (train phase) 138/300
# Finished in 6.176718473434448 (s)
# ------------------------------
# Iteration (train phase) 139/300
# Finished in 6.213111877441406 (s)
# ------------------------------
# Iteration (train phase) 140/300
# Finished in 6.1490209102630615 (s)
# ------------------------------
# Iteration (train phase) 141/300
# Finished in 6.112643480300903 (s)
# ------------------------------
# Iteration (train phase) 142/300
# Finished in 6.137652635574341 (s)
# ------------------------------
# Iteration (train phase) 143/300
# Finished in 6.141919136047363 (s)
# ------------------------------
# Iteration (train phase) 144/300
# Finished in 6.132227182388306 (s)
# ------------------------------
# Iteration (train phase) 145/300
# Finished in 6.103456497192383 (s)
# ------------------------------
# Iteration (train phase) 146/300
# Finished in 6.1656272411346436 (s)
# ------------------------------
# Iteration (train phase) 147/300
# Finished in 6.061689376831055 (s)
# ------------------------------
# Iteration (train phase) 148/300
# Finished in 6.176282644271851 (s)
# ------------------------------
# Iteration (train phase) 149/300
# Finished in 6.308584451675415 (s)
# ------------------------------
# Iteration (train phase) 150/300
# Finished in 6.073601245880127 (s)
# ------------------------------
# Iteration (train phase) 151/300
# Finished in 6.06970477104187 (s)
# ------------------------------
# Iteration (train phase) 152/300
# Finished in 6.1044933795928955 (s)
# ------------------------------
# Iteration (train phase) 153/300
# Finished in 6.12517786026001 (s)
# ------------------------------
# Iteration (train phase) 154/300
# Finished in 6.106878995895386 (s)
# ------------------------------
# Iteration (train phase) 155/300
# Finished in 6.054471731185913 (s)
# ------------------------------
# Iteration (train phase) 156/300
# Finished in 6.091934442520142 (s)
# ------------------------------
# Iteration (train phase) 157/300
# Finished in 6.172493934631348 (s)
# ------------------------------
# Iteration (train phase) 158/300
# Finished in 6.112772703170776 (s)
# ------------------------------
# Iteration (train phase) 159/300
# Finished in 6.2619099617004395 (s)
# ------------------------------
# Iteration (train phase) 160/300
# Finished in 6.173297882080078 (s)
# ------------------------------
# Iteration (train phase) 161/300
# Finished in 6.234145641326904 (s)
# ------------------------------
# Iteration (train phase) 162/300
# Finished in 6.1405134201049805 (s)
# ------------------------------
# Iteration (train phase) 163/300
# Finished in 6.118685007095337 (s)
# ------------------------------
# Iteration (train phase) 164/300
# Finished in 6.115964412689209 (s)
# ------------------------------
# Iteration (train phase) 165/300
# Finished in 6.172398567199707 (s)
# ------------------------------
# Iteration (train phase) 166/300
# Finished in 6.091020345687866 (s)
# ------------------------------
# Iteration (train phase) 167/300
# Finished in 6.170606374740601 (s)
# ------------------------------
# Iteration (train phase) 168/300
# Finished in 6.080779552459717 (s)
# ------------------------------
# Iteration (train phase) 169/300
# Finished in 6.1994946002960205 (s)
# ------------------------------
# Iteration (train phase) 170/300
# Finished in 6.193323612213135 (s)
# ------------------------------
# Iteration (train phase) 171/300
# Finished in 6.166696786880493 (s)
# ------------------------------
# Iteration (train phase) 172/300
# Finished in 6.1799094676971436 (s)
# ------------------------------
# Iteration (train phase) 173/300
# Finished in 6.149545669555664 (s)
# ------------------------------
# Iteration (train phase) 174/300
# Finished in 6.146792411804199 (s)
# ------------------------------
# Iteration (train phase) 175/300
# Finished in 6.1786322593688965 (s)
# ------------------------------
# Iteration (train phase) 176/300
# Finished in 6.0777037143707275 (s)
# ------------------------------
# Iteration (train phase) 177/300
# Finished in 6.072278022766113 (s)
# ------------------------------
# Iteration (train phase) 178/300
# Finished in 6.164484024047852 (s)
# ------------------------------
# Iteration (train phase) 179/300
# Finished in 6.1776652336120605 (s)
# ------------------------------
# Iteration (train phase) 180/300
# Finished in 6.084936141967773 (s)
# ------------------------------
# Iteration (train phase) 181/300
# Finished in 6.0949225425720215 (s)
# ------------------------------
# Iteration (train phase) 182/300
# Finished in 6.287304878234863 (s)
# ------------------------------
# Iteration (train phase) 183/300
# Finished in 6.12030816078186 (s)
# ------------------------------
# Iteration (train phase) 184/300
# Finished in 6.147416591644287 (s)
# ------------------------------
# Iteration (train phase) 185/300
# Finished in 6.0904176235198975 (s)
# ------------------------------
# Iteration (train phase) 186/300
# Finished in 6.194475412368774 (s)
# ------------------------------
# Iteration (train phase) 187/300
# Finished in 6.125700235366821 (s)
# ------------------------------
# Iteration (train phase) 188/300
# Finished in 6.07487678527832 (s)
# ------------------------------
# Iteration (train phase) 189/300
# Finished in 6.105248928070068 (s)
# ------------------------------
# Iteration (train phase) 190/300
# Finished in 6.121607542037964 (s)
# ------------------------------
# Iteration (train phase) 191/300
# Finished in 6.087308406829834 (s)
# ------------------------------
# Iteration (train phase) 192/300
# Finished in 6.103392124176025 (s)
# ------------------------------
# Iteration (train phase) 193/300
# Finished in 6.124147415161133 (s)
# ------------------------------
# Iteration (train phase) 194/300
# Finished in 6.157482862472534 (s)
# ------------------------------
# Iteration (train phase) 195/300
# Finished in 6.091580390930176 (s)
# ------------------------------
# Iteration (train phase) 196/300
# Finished in 6.293565988540649 (s)
# ------------------------------
# Iteration (train phase) 197/300
# Finished in 6.11490273475647 (s)
# ------------------------------
# Iteration (train phase) 198/300
# Finished in 6.144727945327759 (s)
# ------------------------------
# Iteration (train phase) 199/300
# Finished in 6.164083480834961 (s)
# ------------------------------
# Iteration (train phase) 200/300
# Finished in 6.172910451889038 (s)
# ------------------------------
# Iteration (train phase) 201/300
# Finished in 6.125708818435669 (s)
# ------------------------------
# Iteration (train phase) 202/300
# Finished in 6.283704042434692 (s)
# ------------------------------
# Iteration (train phase) 203/300
# Finished in 6.260136127471924 (s)
# ------------------------------
# Iteration (train phase) 204/300
# Finished in 6.15108585357666 (s)
# ------------------------------
# Iteration (train phase) 205/300
# Finished in 6.150655031204224 (s)
# ------------------------------
# Iteration (train phase) 206/300
# Finished in 6.081146717071533 (s)
# ------------------------------
# Iteration (train phase) 207/300
# Finished in 6.0984814167022705 (s)
# ------------------------------
# Iteration (train phase) 208/300
# Finished in 6.1188342571258545 (s)
# ------------------------------
# Iteration (train phase) 209/300
# Finished in 6.185143709182739 (s)
# ------------------------------
# Iteration (train phase) 210/300
# Finished in 6.1115312576293945 (s)
# ------------------------------
# Iteration (train phase) 211/300
# Finished in 6.220974445343018 (s)
# ------------------------------
# Iteration (train phase) 212/300
# Finished in 6.096096038818359 (s)
# ------------------------------
# Iteration (train phase) 213/300
# Finished in 6.389638662338257 (s)
# ------------------------------
# Iteration (train phase) 214/300
# Finished in 6.276784896850586 (s)
# ------------------------------
# Iteration (train phase) 215/300
# Finished in 6.11168098449707 (s)
# ------------------------------
# Iteration (train phase) 216/300
# Finished in 6.142680644989014 (s)
# ------------------------------
# Iteration (train phase) 217/300
# Finished in 6.175952434539795 (s)
# ------------------------------
# Iteration (train phase) 218/300
# Finished in 6.0439417362213135 (s)
# ------------------------------
# Iteration (train phase) 219/300
# Finished in 6.105358600616455 (s)
# ------------------------------
# Iteration (train phase) 220/300
# Finished in 6.0846686363220215 (s)
# ------------------------------
# Iteration (train phase) 221/300
# Finished in 6.149338483810425 (s)
# ------------------------------
# Iteration (train phase) 222/300
# Finished in 6.055524587631226 (s)
# ------------------------------
# Iteration (train phase) 223/300
# Finished in 6.290940046310425 (s)
# ------------------------------
# Iteration (train phase) 224/300
# Finished in 6.128575325012207 (s)
# ------------------------------
# Iteration (train phase) 225/300
# Finished in 6.138177156448364 (s)
# ------------------------------
# Iteration (train phase) 226/300
# Finished in 6.249692916870117 (s)
# ------------------------------
# Iteration (train phase) 227/300
# Finished in 6.165644884109497 (s)
# ------------------------------
# Iteration (train phase) 228/300
# Finished in 6.134908676147461 (s)
# ------------------------------
# Iteration (train phase) 229/300
# Finished in 6.170823097229004 (s)
# ------------------------------
# Iteration (train phase) 230/300
# Finished in 6.168804168701172 (s)
# ------------------------------
# Iteration (train phase) 231/300
# Finished in 6.12676215171814 (s)
# ------------------------------
# Iteration (train phase) 232/300
# Finished in 6.1601738929748535 (s)
# ------------------------------
# Iteration (train phase) 233/300
# Finished in 6.093893527984619 (s)
# ------------------------------
# Iteration (train phase) 234/300
# Finished in 6.101568698883057 (s)
# ------------------------------
# Iteration (train phase) 235/300
# Finished in 6.163246154785156 (s)
# ------------------------------
# Iteration (train phase) 236/300
# Finished in 6.437199831008911 (s)
# ------------------------------
# Iteration (train phase) 237/300
# Finished in 6.224379301071167 (s)
# ------------------------------
# Iteration (train phase) 238/300
# Finished in 6.110449314117432 (s)
# ------------------------------
# Iteration (train phase) 239/300
# Finished in 6.136898517608643 (s)
# ------------------------------
# Iteration (train phase) 240/300
# Finished in 6.219955682754517 (s)
# ------------------------------
# Iteration (train phase) 241/300
# Finished in 6.161733865737915 (s)
# ------------------------------
# Iteration (train phase) 242/300
# Finished in 6.140587568283081 (s)
# ------------------------------
# Iteration (train phase) 243/300
# Finished in 6.189744710922241 (s)
# ------------------------------
# Iteration (train phase) 244/300
# Finished in 6.234832763671875 (s)
# ------------------------------
# Iteration (train phase) 245/300
# Finished in 6.174718856811523 (s)
# ------------------------------
# Iteration (train phase) 246/300
# Finished in 6.1490232944488525 (s)
# ------------------------------
# Iteration (train phase) 247/300
# Finished in 6.286572456359863 (s)
# ------------------------------
# Iteration (train phase) 248/300
# Finished in 6.292438268661499 (s)
# ------------------------------
# Iteration (train phase) 249/300
# Finished in 6.139894247055054 (s)
# ------------------------------
# Iteration (train phase) 250/300
# Finished in 6.213475942611694 (s)
# ------------------------------
# Iteration (train phase) 251/300
# Finished in 6.227036952972412 (s)
# ------------------------------
# Iteration (train phase) 252/300
# Finished in 6.133461952209473 (s)
# ------------------------------
# Iteration (train phase) 253/300
# Finished in 6.224959373474121 (s)
# ------------------------------
# Iteration (train phase) 254/300
# Finished in 6.144521713256836 (s)
# ------------------------------
# Iteration (train phase) 255/300
# Finished in 6.17582106590271 (s)
# ------------------------------
# Iteration (train phase) 256/300
# Finished in 6.154924154281616 (s)
# ------------------------------
# Iteration (train phase) 257/300
# Finished in 6.105026721954346 (s)
# ------------------------------
# Iteration (train phase) 258/300
# Finished in 6.609236717224121 (s)
# ------------------------------
# Iteration (train phase) 259/300
# Finished in 6.1453046798706055 (s)
# ------------------------------
# Iteration (train phase) 260/300
# Finished in 6.169114828109741 (s)
# ------------------------------
# Iteration (train phase) 261/300
# Finished in 6.09254264831543 (s)
# ------------------------------
# Iteration (train phase) 262/300
# Finished in 6.14276909828186 (s)
# ------------------------------
# Iteration (train phase) 263/300
# Finished in 6.152536153793335 (s)
# ------------------------------
# Iteration (train phase) 264/300
# Finished in 6.097742319107056 (s)
# ------------------------------
# Iteration (train phase) 265/300
# Finished in 6.1215500831604 (s)
# ------------------------------
# Iteration (train phase) 266/300
# Finished in 6.025763750076294 (s)
# ------------------------------
# Iteration (train phase) 267/300
# Finished in 6.129085540771484 (s)
# ------------------------------
# Iteration (train phase) 268/300
# Finished in 6.133318662643433 (s)
# ------------------------------
# Iteration (train phase) 269/300
# Finished in 6.160851240158081 (s)
# ------------------------------
# Iteration (train phase) 270/300
# Finished in 6.1018102169036865 (s)
# ------------------------------
# Iteration (train phase) 271/300
# Finished in 6.186438322067261 (s)
# ------------------------------
# Iteration (train phase) 272/300
# Finished in 6.170592308044434 (s)
# ------------------------------
# Iteration (train phase) 273/300
# Finished in 6.183268308639526 (s)
# ------------------------------
# Iteration (train phase) 274/300
# Finished in 6.1786932945251465 (s)
# ------------------------------
# Iteration (train phase) 275/300
# Finished in 6.111423969268799 (s)
# ------------------------------
# Iteration (train phase) 276/300
# Finished in 6.208900690078735 (s)
# ------------------------------
# Iteration (train phase) 277/300
# Finished in 6.20195198059082 (s)
# ------------------------------
# Iteration (train phase) 278/300
# Finished in 6.204976797103882 (s)
# ------------------------------
# Iteration (train phase) 279/300
# Finished in 6.2714033126831055 (s)
# ------------------------------
# Iteration (train phase) 280/300
# Finished in 6.1906044483184814 (s)
# ------------------------------
# Iteration (train phase) 281/300
# Finished in 6.104571342468262 (s)
# ------------------------------
# Iteration (train phase) 282/300
# Finished in 6.136287450790405 (s)
# ------------------------------
# Iteration (train phase) 283/300
# Finished in 6.162479877471924 (s)
# ------------------------------
# Iteration (train phase) 284/300
# Finished in 6.193866491317749 (s)
# ------------------------------
# Iteration (train phase) 285/300
# Finished in 6.09975790977478 (s)
# ------------------------------
# Iteration (train phase) 286/300
# Finished in 6.105642080307007 (s)
# ------------------------------
# Iteration (train phase) 287/300
# Finished in 6.143497705459595 (s)
# ------------------------------
# Iteration (train phase) 288/300
# Finished in 6.124220609664917 (s)
# ------------------------------
# Iteration (train phase) 289/300
# Finished in 6.171446084976196 (s)
# ------------------------------
# Iteration (train phase) 290/300
# Finished in 6.145704507827759 (s)
# ------------------------------
# Iteration (train phase) 291/300
# Finished in 6.106353759765625 (s)
# ------------------------------
# Iteration (train phase) 292/300
# Finished in 6.218487739562988 (s)
# ------------------------------
# Iteration (train phase) 293/300
# Finished in 6.095918893814087 (s)
# ------------------------------
# Iteration (train phase) 294/300
# Finished in 6.136435031890869 (s)
# ------------------------------
# Iteration (train phase) 295/300
# Finished in 6.125710487365723 (s)
# ------------------------------
# Iteration (train phase) 296/300
# Finished in 6.242589950561523 (s)
# ------------------------------
# Iteration (train phase) 297/300
# Finished in 6.132417440414429 (s)
# ------------------------------
# Iteration (train phase) 298/300
# Finished in 6.1720054149627686 (s)
# ------------------------------
# Iteration (train phase) 299/300
# Finished in 6.340117454528809 (s)
# ------------------------------
# Iteration (train phase) 300/300
# Finished in 6.1569085121154785 (s)
# ------------------------------
# Iteration (validation phase) 1/100
# Finished in 6.021411657333374 (s)
# ------------------------------
# Iteration (validation phase) 2/100
# Finished in 5.876377820968628 (s)
# ------------------------------
# Iteration (validation phase) 3/100
# Finished in 5.831875801086426 (s)
# ------------------------------
# Iteration (validation phase) 4/100
# Finished in 6.057408094406128 (s)
# ------------------------------
# Iteration (validation phase) 5/100
# Finished in 5.8443968296051025 (s)
# ------------------------------
# Iteration (validation phase) 6/100
# Finished in 5.786828994750977 (s)
# ------------------------------
# Iteration (validation phase) 7/100
# Finished in 5.815110921859741 (s)
# ------------------------------
# Iteration (validation phase) 8/100
# Finished in 5.951088190078735 (s)
# ------------------------------
# Iteration (validation phase) 9/100
# Finished in 5.852753400802612 (s)
# ------------------------------
# Iteration (validation phase) 10/100
# Finished in 5.867527723312378 (s)
# ------------------------------
# Iteration (validation phase) 11/100
# Finished in 5.8841962814331055 (s)
# ------------------------------
# Iteration (validation phase) 12/100
# Finished in 5.853977203369141 (s)
# ------------------------------
# Iteration (validation phase) 13/100
# Finished in 5.8500401973724365 (s)
# ------------------------------
# Iteration (validation phase) 14/100
# Finished in 5.945211410522461 (s)
# ------------------------------
# Iteration (validation phase) 15/100
# Finished in 5.8856589794158936 (s)
# ------------------------------
# Iteration (validation phase) 16/100
# Finished in 5.977155923843384 (s)
# ------------------------------
# Iteration (validation phase) 17/100
# Finished in 5.848085165023804 (s)
# ------------------------------
# Iteration (validation phase) 18/100
# Finished in 5.878057241439819 (s)
# ------------------------------
# Iteration (validation phase) 19/100
# Finished in 5.851052284240723 (s)
# ------------------------------
# Iteration (validation phase) 20/100
# Finished in 5.874801158905029 (s)
# ------------------------------
# Iteration (validation phase) 21/100
# Finished in 5.8583598136901855 (s)
# ------------------------------
# Iteration (validation phase) 22/100
# Finished in 5.932292938232422 (s)
# ------------------------------
# Iteration (validation phase) 23/100
# Finished in 5.84305477142334 (s)
# ------------------------------
# Iteration (validation phase) 24/100
# Finished in 5.854174613952637 (s)
# ------------------------------
# Iteration (validation phase) 25/100
# Finished in 5.885813474655151 (s)
# ------------------------------
# Iteration (validation phase) 26/100
# Finished in 5.9379003047943115 (s)
# ------------------------------
# Iteration (validation phase) 27/100
# Finished in 5.922403812408447 (s)
# ------------------------------
# Iteration (validation phase) 28/100
# Finished in 5.896260499954224 (s)
# ------------------------------
# Iteration (validation phase) 29/100
# Finished in 5.932081699371338 (s)
# ------------------------------
# Iteration (validation phase) 30/100
# Finished in 5.804565906524658 (s)
# ------------------------------
# Iteration (validation phase) 31/100
# Finished in 5.941723585128784 (s)
# ------------------------------
# Iteration (validation phase) 32/100
# Finished in 5.916429281234741 (s)
# ------------------------------
# Iteration (validation phase) 33/100
# Finished in 5.8853654861450195 (s)
# ------------------------------
# Iteration (validation phase) 34/100
# Finished in 5.847635507583618 (s)
# ------------------------------
# Iteration (validation phase) 35/100
# Finished in 5.852696180343628 (s)
# ------------------------------
# Iteration (validation phase) 36/100
# Finished in 5.891005754470825 (s)
# ------------------------------
# Iteration (validation phase) 37/100
# Finished in 5.949744701385498 (s)
# ------------------------------
# Iteration (validation phase) 38/100
# Finished in 5.981235504150391 (s)
# ------------------------------
# Iteration (validation phase) 39/100
# Finished in 5.873043775558472 (s)
# ------------------------------
# Iteration (validation phase) 40/100
# Finished in 5.892777681350708 (s)
# ------------------------------
# Iteration (validation phase) 41/100
# Finished in 5.843078851699829 (s)
# ------------------------------
# Iteration (validation phase) 42/100
# Finished in 5.869506359100342 (s)
# ------------------------------
# Iteration (validation phase) 43/100
# Finished in 5.939403533935547 (s)
# ------------------------------
# Iteration (validation phase) 44/100
# Finished in 5.94298791885376 (s)
# ------------------------------
# Iteration (validation phase) 45/100
# Finished in 5.888023614883423 (s)
# ------------------------------
# Iteration (validation phase) 46/100
# Finished in 5.921212673187256 (s)
# ------------------------------
# Iteration (validation phase) 47/100
# Finished in 5.928278923034668 (s)
# ------------------------------
# Iteration (validation phase) 48/100
# Finished in 6.010217189788818 (s)
# ------------------------------
# Iteration (validation phase) 49/100
# Finished in 6.066486358642578 (s)
# ------------------------------
# Iteration (validation phase) 50/100
# Finished in 5.955412149429321 (s)
# ------------------------------
# Iteration (validation phase) 51/100
# Finished in 6.062031030654907 (s)
# ------------------------------
# Iteration (validation phase) 52/100
# Finished in 6.022489547729492 (s)
# ------------------------------
# Iteration (validation phase) 53/100
# Finished in 6.0522332191467285 (s)
# ------------------------------
# Iteration (validation phase) 54/100
# Finished in 6.030785083770752 (s)
# ------------------------------
# Iteration (validation phase) 55/100
# Finished in 6.01690411567688 (s)
# ------------------------------
# Iteration (validation phase) 56/100
# Finished in 5.955190420150757 (s)
# ------------------------------
# Iteration (validation phase) 57/100
# Finished in 5.871548891067505 (s)
# ------------------------------
# Iteration (validation phase) 58/100
# Finished in 5.859750270843506 (s)
# ------------------------------
# Iteration (validation phase) 59/100
# Finished in 5.920705556869507 (s)
# ------------------------------
# Iteration (validation phase) 60/100
# Finished in 5.8726646900177 (s)
# ------------------------------
# Iteration (validation phase) 61/100
# Finished in 5.854966878890991 (s)
# ------------------------------
# Iteration (validation phase) 62/100
# Finished in 5.854862689971924 (s)
# ------------------------------
# Iteration (validation phase) 63/100
# Finished in 5.840303897857666 (s)
# ------------------------------
# Iteration (validation phase) 64/100
# Finished in 5.8792266845703125 (s)
# ------------------------------
# Iteration (validation phase) 65/100
# Finished in 5.873475790023804 (s)
# ------------------------------
# Iteration (validation phase) 66/100
# Finished in 5.84799861907959 (s)
# ------------------------------
# Iteration (validation phase) 67/100
# Finished in 5.851312875747681 (s)
# ------------------------------
# Iteration (validation phase) 68/100
# Finished in 5.862513303756714 (s)
# ------------------------------
# Iteration (validation phase) 69/100
# Finished in 5.854089736938477 (s)
# ------------------------------
# Iteration (validation phase) 70/100
# Finished in 5.8825764656066895 (s)
# ------------------------------
# Iteration (validation phase) 71/100
# Finished in 5.860372304916382 (s)
# ------------------------------
# Iteration (validation phase) 72/100
# Finished in 5.88085412979126 (s)
# ------------------------------
# Iteration (validation phase) 73/100
# Finished in 5.98247218132019 (s)
# ------------------------------
# Iteration (validation phase) 74/100
# Finished in 5.898643970489502 (s)
# ------------------------------
# Iteration (validation phase) 75/100
# Finished in 5.907242059707642 (s)
# ------------------------------
# Iteration (validation phase) 76/100
# Finished in 5.977072238922119 (s)
# ------------------------------
# Iteration (validation phase) 77/100
# Finished in 6.023497581481934 (s)
# ------------------------------
# Iteration (validation phase) 78/100
# Finished in 5.8650062084198 (s)
# ------------------------------
# Iteration (validation phase) 79/100
# Finished in 5.883246898651123 (s)
# ------------------------------
# Iteration (validation phase) 80/100
# Finished in 5.8675007820129395 (s)
# ------------------------------
# Iteration (validation phase) 81/100
# Finished in 5.8791797161102295 (s)
# ------------------------------
# Iteration (validation phase) 82/100
# Finished in 5.859560966491699 (s)
# ------------------------------
# Iteration (validation phase) 83/100
# Finished in 5.990652084350586 (s)
# ------------------------------
# Iteration (validation phase) 84/100
# Finished in 5.886990308761597 (s)
# ------------------------------
# Iteration (validation phase) 85/100
# Finished in 6.021184206008911 (s)
# ------------------------------
# Iteration (validation phase) 86/100
# Finished in 5.881539583206177 (s)
# ------------------------------
# Iteration (validation phase) 87/100
# Finished in 5.800464391708374 (s)
# ------------------------------
# Iteration (validation phase) 88/100
# Finished in 5.843148231506348 (s)
# ------------------------------
# Iteration (validation phase) 89/100
# Finished in 5.8422346115112305 (s)
# ------------------------------
# Iteration (validation phase) 90/100
# Finished in 5.861875772476196 (s)
# ------------------------------
# Iteration (validation phase) 91/100
# Finished in 5.786440134048462 (s)
# ------------------------------
# Iteration (validation phase) 92/100
# Finished in 5.870544910430908 (s)
# ------------------------------
# Iteration (validation phase) 93/100
# Finished in 5.8976359367370605 (s)
# ------------------------------
# Iteration (validation phase) 94/100
# Finished in 5.867982625961304 (s)
# ------------------------------
# Iteration (validation phase) 95/100
# Finished in 5.896561622619629 (s)
# ------------------------------
# Iteration (validation phase) 96/100
# Finished in 5.9363343715667725 (s)
# ------------------------------
# Iteration (validation phase) 97/100
# Finished in 5.889841556549072 (s)
# ------------------------------
# Iteration (validation phase) 98/100
# Finished in 5.811168909072876 (s)
# ------------------------------
# Iteration (validation phase) 99/100
# Finished in 5.867368459701538 (s)
# ------------------------------
# Iteration (validation phase) 100/100
# Finished in 5.867044687271118 (s)
# Epoch 1 - accuracy: 0.995
# ------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-daf5d8867a02> in <module>
#      79
#      80     # Save model
# ---> 81     model_file_path = model_path + "resnet18_trained_model_epoch_{}.pth".format(epoch+1)
#      82     torch.save(model.state_dict(), model_file_path)
#      83
#
# NameError: name 'model_path' is not defined

# %% [markdown]
# <b>Print out the Accuracy and plot the loss stored in the list <code>loss_list</code> for every iteration and take a screen shot.</b>

# %%
accuracy
# Out:
# 0.9953

# %%
plt.plot(loss_list)
plt.xlabel("iteration")
plt.ylabel("loss")
plt.show()

# %% [markdown]
# <h2 id="Question_3">Question 3:Find the misclassified samples</h2>

# %% [markdown]
# <b>Identify the first four misclassified samples using the validation data:</b>

# %%
count = 0
max_num_of_items = 4  # first four mis-classified samples
validation_loader_batch_one = torch.utils.data.DataLoader(dataset=validation_dataset, batch_size=1)

for i, (x_test, y_test) in enumerate(validation_loader_batch_one):
    # set model to eval
    model.eval()
    
    # make a prediction
    z = model(x_test)
    
    # find max
    _, yhat = torch.max(z.data, 1)
    
    # print mis-classified samples
    if yhat != y_test:
        print("Sample : {}; Expected Label: {}; Obtained Label: {}".format(str(i), str(y_test), str(yhat)))
        count += 1
        if count >= max_num_of_items:
            break
# Out:
# Sample : 690; Expected Label: tensor([1]); Obtained Label: tensor([0])
# Sample : 776; Expected Label: tensor([1]); Obtained Label: tensor([0])
# Sample : 1442; Expected Label: tensor([1]); Obtained Label: tensor([0])
# Sample : 1447; Expected Label: tensor([0]); Obtained Label: tensor([1])

# %% [markdown]
# <a href="https://dataplatform.cloud.ibm.com/docs/content/wsj/analyze-data/share-notebooks.html"> CLICK HERE </a> Click here to see how to share your notebook.

# %% [markdown]
# <h2>About the Authors:</h2>
#
# <a href="https://www.linkedin.com/in/joseph-s-50398b136/">Joseph Santarcangelo</a> has a PhD in Electrical Engineering, his research focused on using machine learning, signal processing, and computer vision to determine how videos impact human cognition. Joseph has been working for IBM since he completed his PhD.

# %% [markdown]
# Copyright &copy; 2018 <a href="cognitiveclass.ai?utm_source=bducopyrightlink&utm_medium=dswb&utm_campaign=bdu">cognitiveclass.ai</a>. This notebook and its source code are released under the terms of the <a href="https://bigdatauniversity.com/mit-license/">MIT License</a>.
